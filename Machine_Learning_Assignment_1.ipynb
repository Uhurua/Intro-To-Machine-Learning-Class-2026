# %% [markdown]
# <a href="https://colab.research.google.com/github/Uhurua/Intro-To-Machine-Learning-Class-2026/blob/main/Machine_Learning_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
BostonBake = pd.read_csv("https://raw.githubusercontent.com/Uhurua/Intro-To-Machine-Learning-Class-2026/refs/heads/main/train.csv")
BostonBake
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
# Pandas and NumPy import
import numpy as np
import pandas as pd

# Set the features by dropping 'ID' and 'medv' columns from BostonBake
df = BostonBake.drop(columns=['ID', 'medv'])

# Set the target by selecting the 'medv' column from BostonBake
target = BostonBake[['medv']]

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
# Fit and make the predictions by the model
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared (uncentered):                   0.904
# Model:                            OLS   Adj. R-squared (uncentered):              0.903
# Method:                 Least Squares   F-statistic:                              3117.
# Date:                Wed, 05 Aug 2026   Prob (F-statistic):                   8.25e-171
# Time:                        00:04:55   Log-Likelihood:                         -1148.5
# No. Observations:                 333   AIC:                                      2299.
# Df Residuals:                     332   BIC:                                      2303.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.476
# Model:                            OLS   Adj. R-squared:                  0.474
# Method:                 Least Squares   F-statistic:                     300.1
# Date:                Wed, 05 Aug 2026   Prob (F-statistic):           2.59e-48
# Time:                        00:10:42   Log-Likelihood:                -1102.6
# No. Observations:                 333   AIC:                             2209.
# Df Residuals:                     331   BIC:                             2217.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -33.5367      3.270    -10.254      0.000     -39.970     -27.103
# ...

# %%
X = df[["rm", "lstat"]]
y = target["medv"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared (uncentered):                   0.949
# Model:                            OLS   Adj. R-squared (uncentered):              0.949
# Method:                 Least Squares   F-statistic:                              3084.
# Date:                Wed, 05 Aug 2026   Prob (F-statistic):                   1.03e-214
# Time:                        00:16:35   Log-Likelihood:                         -1042.5
# No. Observations:                 333   AIC:                                      2089.
# Df Residuals:                     331   BIC:                                      2097.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
from sklearn import linear_model

# %%
X = df
y = target["medv"]

lm = linear_model.LinearRegression()
model = lm.fit(X,y)

# %%
predictions = lm.predict(X)
print(predictions[0:5])
# Out:
# [29.74869344 24.61772028 28.6693721  27.78186693 22.31841323]

# %%
lm.score(X,y)
# Out:
# 0.7331394355527803

# %%
lm.coef_
# Out:
# array([-5.24893379e-02,  4.74448677e-02,  5.38552422e-02,  3.78486439e+00,
#        -1.57396571e+01,  3.76883175e+00, -4.62660241e-03, -1.54882312e+00,
#         3.28967093e-01, -1.28664959e-02, -8.56975746e-01,  1.16659048e-02,
#        -6.00315456e-01])
